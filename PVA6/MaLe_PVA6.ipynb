# %% [markdown]
# # MaLe PVA6 - Aufgabe
#
# Vergleichen Sie die folgenden Regressionsstechniken:
#
# - Entscheidungsbäume
# - lineare Regression
#
# Wenden Sie dazu diese Techniken auf den Boston- und Diabetes-Datensatz an.
#
# Geben Sie einerseits Ihren Code ab sowie eine Dokument, indem Sie Ihre Ergebnisse kommentieren und interpretieren.
#
# **Inhalt**
#
# 1. Diabetes Dataset
#
# 1.1 sklearn.linear_model.LinearRegression
#
# 1.2 sklearn.tree.DecisionTreeRegressor
#
# 2. Boston Dataset
#
# 2.1 sklearn.linear_model.LinearRegression
#
# 2.2 sklearn.tree.DecisionTreeRegressor
#
# 3. Interpretation Regressionstechniken
#
# 3.1 Diabetes Dataset
#
# 3.2 Boston Dataset

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
from sklearn import datasets, tree, linear_model
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, mean_squared_error, r2_score, precision_recall_fscore_support, f1_score

# %% [markdown]
# # 1. Diabetes Datensatz
# Im folgenden Abschnitt wird auf den Diabetes Datensatz zwei lineare Regression Methodiken angewendet:
#
# - `sklearn.linear_model.LinearRegression`
# - `sklearn.tree.DecisionTreeRegressor`

# %%
diabetes_dataset = datasets.load_diabetes()
print(diabetes_dataset.DESCR)
# Out:
# .. _diabetes_dataset:
#
# Diabetes dataset
# ----------------
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# **Data Set Characteristics:**
#
#   :Number of Instances: 442
#
#   :Number of Attributes: First 10 columns are numeric predictive values
#
#   :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
#   :Attribute Information:
#       - age     age in years
#       - sex
#       - bmi     body mass index
#       - bp      average blood pressure
#       - s1      tc, T-Cells (a type of white blood cells)
#       - s2      ldl, low-density lipoproteins
#       - s3      hdl, high-density lipoproteins
#       - s4      tch, thyroid stimulating hormone
#       - s5      ltg, lamotrigine
# ...

# %%
# example instance with the 10 features
diabetes_dataset['data'][0]
# Out:
# array([ 0.03807591,  0.05068012,  0.06169621,  0.02187235, -0.0442235 ,
#        -0.03482076, -0.04340085, -0.00259226,  0.01990842, -0.01764613])

# %% [markdown]
# ## 1.1 sklearn.linear_model.LinearRegression

# %%
diabetes_dataset_X, diabetes_dataset_y = datasets.load_diabetes(return_X_y=True)

# use only one feature to show a 2d graph of the result
diabetes_dataset_X = diabetes_dataset_X[:, np.newaxis, 2]

# split into train and test data
diabetes_dataset_X_train = diabetes_dataset_X[:-20]
diabetes_dataset_X_test = diabetes_dataset_X[-20:]

diabetes_dataset_y_train = diabetes_dataset_y[:-20]
diabetes_dataset_y_test = diabetes_dataset_y[-20:]

# linear regression
regr = linear_model.LinearRegression()

# model training
regr.fit(diabetes_dataset_X_train, diabetes_dataset_y_train)

# predictions
diabetes_dataset_y_predictions = regr.predict(diabetes_dataset_X_test)


print("Performance of the model:")

# The root mean squared error: 0 is perfect prediction
print('Root Mean squared error: %.2f'
      % math.sqrt(mean_squared_error(diabetes_dataset_y_test, diabetes_dataset_y_predictions)))
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'
      % r2_score(diabetes_dataset_y_test, diabetes_dataset_y_predictions))

# Plot outputs
plt.scatter(diabetes_dataset_X_test, diabetes_dataset_y_test,  color='black')
plt.plot(diabetes_dataset_X_test, diabetes_dataset_y_predictions, color='blue', linewidth=3)
plt.show()
# Out:
# Performance of the model:
# Root Mean squared error: 50.48
# Coefficient of determination: 0.47

# %%
# test with more features to see if performance increases

diabetes_dataset_X, diabetes_dataset_y = datasets.load_diabetes(return_X_y=True)

# split into train and test data
diabetes_dataset_X_train = diabetes_dataset_X[:-20]
diabetes_dataset_X_test = diabetes_dataset_X[-20:]

diabetes_dataset_y_train = diabetes_dataset_y[:-20]
diabetes_dataset_y_test = diabetes_dataset_y[-20:]

# linear regression
regr = linear_model.LinearRegression()

# model training
regr.fit(diabetes_dataset_X_train, diabetes_dataset_y_train)

# predictions
diabetes_dataset_y_predictions = regr.predict(diabetes_dataset_X_test)


print("Performance of the model:")

# The root mean squared error: 0 is perfect prediction
print('Root Mean squared error: %.2f'
      % math.sqrt(mean_squared_error(diabetes_dataset_y_test, diabetes_dataset_y_predictions)))
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'
      % r2_score(diabetes_dataset_y_test, diabetes_dataset_y_predictions))
# Out:
# Performance of the model:
# Root Mean squared error: 44.77
# Coefficient of determination: 0.59

# %% [markdown]
# ## 1.2 sklearn.tree.DecisionTreeRegressor

# %%
diabetes_dataset_X, diabetes_dataset_y = datasets.load_diabetes(return_X_y=True)

# use only one feature to show a 2d graph of the result
diabetes_dataset_X = diabetes_dataset_X[:, np.newaxis, 2]

# split into train and test data
diabetes_dataset_X_train = diabetes_dataset_X[:-20]
diabetes_dataset_X_test = diabetes_dataset_X[-20:]

diabetes_dataset_y_train = diabetes_dataset_y[:-20]
diabetes_dataset_y_test = diabetes_dataset_y[-20:]

# linear regression with DecisionTreeRegressor
regr = DecisionTreeRegressor(random_state=0)#, max_depth=2)

# model training
regr.fit(diabetes_dataset_X_train, diabetes_dataset_y_train)

# predictions
diabetes_dataset_y_predictions = regr.predict(diabetes_dataset_X_test)


print("Performance of the model:")

# The root mean squared error: 0 is perfect prediction
print('Root Mean squared error: %.2f'
      % math.sqrt(mean_squared_error(diabetes_dataset_y_test, diabetes_dataset_y_predictions)))
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'
      % r2_score(diabetes_dataset_y_test, diabetes_dataset_y_predictions))

# Plot outputs
plt.scatter(diabetes_dataset_X_test, diabetes_dataset_y_test,  color='black')
plt.scatter(diabetes_dataset_X_test, diabetes_dataset_y_predictions, color='blue', linewidth=3)
plt.show()
# Out:
# Performance of the model:
# Root Mean squared error: 77.04
# Coefficient of determination: -0.23

# %%
# test with more features to see if performance increases

diabetes_dataset_X, diabetes_dataset_y = datasets.load_diabetes(return_X_y=True)

# split into train and test data
diabetes_dataset_X_train = diabetes_dataset_X[:-20]
diabetes_dataset_X_test = diabetes_dataset_X[-20:]

diabetes_dataset_y_train = diabetes_dataset_y[:-20]
diabetes_dataset_y_test = diabetes_dataset_y[-20:]

# linear regression with DecisionTreeRegressor
regr = DecisionTreeRegressor(random_state=0)#, max_depth=2)

# model training
regr.fit(diabetes_dataset_X_train, diabetes_dataset_y_train)

# predictions
diabetes_dataset_y_predictions = regr.predict(diabetes_dataset_X_test)


print("Performance of the model:")

# The root mean squared error: 0 is perfect prediction
print('Root Mean squared error: %.2f'
      % math.sqrt(mean_squared_error(diabetes_dataset_y_test, diabetes_dataset_y_predictions)))
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'
      % r2_score(diabetes_dataset_y_test, diabetes_dataset_y_predictions))
# Out:
# Performance of the model:
# Root Mean squared error: 78.36
# Coefficient of determination: -0.27

# %%
cross_val_score(regr, diabetes_dataset_X_test, diabetes_dataset_y_test, cv=10)
# Out:
# array([-1.39555644e-01, -1.19268293e+01, -9.77216091e-01,  1.04723937e-01,
#         4.59493024e-02,  8.91383198e-01, -7.25377778e+01,  6.81420118e-01,
#        -1.66734694e+01,  8.30027476e-01])

# %%
# plot decistion tree
fig, axes = plt.subplots(nrows = 1,ncols = 1,figsize = (4,4), dpi=400)
tree.plot_tree(regr,
               filled = True);
fig.savefig('imagename.png')

# %% [markdown]
# # 2. Boston Dataset
# Im folgenden Abschnitt wird auf den Boston Datensatz zwei lineare Regression Methodiken angewendet:
#
# - `sklearn.linear_model.LinearRegression`
# - `sklearn.tree.DecisionTreeRegressor`

# %%
boston_dataset = datasets.load_boston()
print(boston_dataset.DESCR)
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
# ...

# %%
# example instance with the 13 features
boston_dataset['data'][0]
# Out:
# array([6.320e-03, 1.800e+01, 2.310e+00, 0.000e+00, 5.380e-01, 6.575e+00,
#        6.520e+01, 4.090e+00, 1.000e+00, 2.960e+02, 1.530e+01, 3.969e+02,
#        4.980e+00])

# %% [markdown]
# ## 2.1 sklearn.linear_model.LinearRegression

# %%
boston_dataset_X, boston_dataset_y = datasets.load_boston(return_X_y=True)

# use only one feature to show a 2d graph of the result
boston_dataset_X = boston_dataset_X[:, np.newaxis, 2]

# split into train and test data
boston_dataset_X_train = boston_dataset_X[:-20]
boston_dataset_X_test = boston_dataset_X[-20:]

boston_dataset_y_train = boston_dataset_y[:-20]
boston_dataset_y_test = boston_dataset_y[-20:]

# linear regression
regr = linear_model.LinearRegression()

# model training
regr.fit(boston_dataset_X_train, boston_dataset_y_train)

# predictions
boston_dataset_y_predictions = regr.predict(boston_dataset_X_test)


print("Performance of the model:")

# The root mean squared error: 0 is perfect prediction
print('Root Mean squared error: %.2f'
      % math.sqrt(mean_squared_error(boston_dataset_y_test, boston_dataset_y_predictions)))
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'
      % r2_score(boston_dataset_y_test, boston_dataset_y_predictions))

# Plot outputs
plt.scatter(boston_dataset_X_test, boston_dataset_y_test,  color='black')
plt.plot(boston_dataset_X_test, boston_dataset_y_predictions, color='blue', linewidth=3)
plt.show()
# Out:
# Performance of the model:
# Root Mean squared error: 4.31
# Coefficient of determination: 0.21

# %%
boston_dataset_X, boston_dataset_y = datasets.load_boston(return_X_y=True)

# split into train and test data
boston_dataset_X_train = boston_dataset_X[:-20]
boston_dataset_X_test = boston_dataset_X[-20:]

boston_dataset_y_train = boston_dataset_y[:-20]
boston_dataset_y_test = boston_dataset_y[-20:]

# linear regression
regr = linear_model.LinearRegression()

# model training
regr.fit(boston_dataset_X_train, boston_dataset_y_train)

# predictions
boston_dataset_y_predictions = regr.predict(boston_dataset_X_test)


print("Performance of the model:")

# The root mean squared error: 0 is perfect prediction
print('Root Mean squared error: %.2f'
      % math.sqrt(mean_squared_error(boston_dataset_y_test, boston_dataset_y_predictions)))
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'
      % r2_score(boston_dataset_y_test, boston_dataset_y_predictions))
# Out:
# Performance of the model:
# Root Mean squared error: 4.23
# Coefficient of determination: 0.24

# %% [markdown]
# ## 2.2 sklearn.tree.DecisionTreeRegressor

# %%
boston_dataset_X, boston_dataset_y = datasets.load_boston(return_X_y=True)

# use only one feature to show a 2d graph of the result
boston_dataset_X = boston_dataset_X[:, np.newaxis, 2]

# split into train and test data
boston_dataset_X_train = boston_dataset_X[:-20]
boston_dataset_X_test = boston_dataset_X[-20:]

boston_dataset_y_train = boston_dataset_y[:-20]
boston_dataset_y_test = boston_dataset_y[-20:]

# linear regression with DecisionTreeRegressor
regr = DecisionTreeRegressor(random_state=0)#, max_depth=2)

# model training
regr.fit(boston_dataset_X_train, boston_dataset_y_train)

# predictions
boston_dataset_y_predictions = regr.predict(boston_dataset_X_test)


print("Performance of the model:")

# The root mean squared error: 0 is perfect prediction
print('Root Mean squared error: %.2f'
      % math.sqrt(mean_squared_error(boston_dataset_y_test, boston_dataset_y_predictions)))
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'
      % r2_score(boston_dataset_y_test, boston_dataset_y_predictions))

# Plot outputs
plt.scatter(boston_dataset_X_test, boston_dataset_y_test,  color='black')
plt.scatter(boston_dataset_X_test, boston_dataset_y_predictions, color='blue', linewidth=3)
plt.show()
# Out:
# Performance of the model:
# Root Mean squared error: 5.05
# Coefficient of determination: -0.09

# %%
boston_dataset_X, boston_dataset_y = datasets.load_boston(return_X_y=True)

# split into train and test data
boston_dataset_X_train = boston_dataset_X[:-20]
boston_dataset_X_test = boston_dataset_X[-20:]

boston_dataset_y_train = boston_dataset_y[:-20]
boston_dataset_y_test = boston_dataset_y[-20:]

# linear regression with DecisionTreeRegressor
regr = DecisionTreeRegressor(random_state=0)#, max_depth=2)

# model training
regr.fit(boston_dataset_X_train, boston_dataset_y_train)

# predictions
boston_dataset_y_predictions = regr.predict(boston_dataset_X_test)


print("Performance of the model:")

# The root mean squared error: 0 is perfect prediction
print('Root Mean squared error: %.2f'
      % math.sqrt(mean_squared_error(boston_dataset_y_test, boston_dataset_y_predictions)))
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'
      % r2_score(boston_dataset_y_test, boston_dataset_y_predictions))
# Out:
# Performance of the model:
# Root Mean squared error: 4.69
# Coefficient of determination: 0.06

# %% [markdown]
# ## 3 Interpretation Regressionstechniken
#
# ### 3.1 Diabetes Dataset
#
# Lineare Regression schneidet besser ab als DecisionTreeRegressor:
# - Root mean squared error: 50.48 (lineare Regression) und 77.04 (DecisionTreeRegressor). Kleinere Fehlerrate bei der linearen Regression, was für sie spricht.
# - R2 Score (Coefficient of determination): 0.47 (lineare Regression) und -0.23 (DecisionTreeRegressor). Der R2 Score für linearen Regression ist naher bei 1, und deshalb besser. Der Score vom DecisionTreeRegressor ist sogar negativ.. (Reference: https://scikit-learn.org/stable/modules/generated/sklearn.metrics.r2_score.html)
#
# Dieses Ergebnis wurde berechnet, wenn bei X nur 1 Feature verwendet wurde. Im einem nächsten Versuch wurden alle Features (10) beim Training verwendet und beide Modelle wurden sichtlich besser, jedoch bleibt, das Lineare-Regressions-Modell besser als das DecisionTreeRegressor-Modell.
#
# ### 3.2 Boston Dataset
#
# Beim Boston Dataset zeigt sich dasselbe Bild, wie beim Diabetes Dataset:
# - Root mean squared error: 4.31 (lineare Regression) und 5.05 (DecisionTreeRegressor)
# - R2 Score (Coefficient of determination): 0.21 (lineare Regression) und -0.09 (DecisionTreeRegressor)
#
# Ebenfalls konnte die Performance für beide Modelle gesteigert werden, wenn alle Features (13) für das Training verwendet wurden.
#
#
#
#
#
# DecistionTree Regression hat eine schlechtere Performance in den Predictions auf Datensätze, welche mehr von den Trainingsdaten variieren, da Overfitting sehr häufig vorkommt. Dafür ist das DecisionTree Regressionsmodell einfach zu verstehen, interpretieren und visualisieren.
#
# Und deshalb kommen ab da an Lineare Regressionsmodelle und neuronale Netzwerke zum Zug. Auch beim Diabetes Datensatz und Boston Datensatz kann man deshalb gut das Lineare Regressionsmodell gebrauchen.
